# %%
#Función completa

import requests
import json

def get_dolar():
    url = "https://mindicador.cl/api/dolar"
    response = requests.get(url)
    return response.json()

dolar_data = get_dolar()
print(json.dumps(dolar_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "version": "1.7.0",
#     "autor": "mindicador.cl",
#     "codigo": "dolar",
#     "nombre": "Dólar observado",
#     "unidad_medida": "Pesos",
#     "serie": [
#         {
#             "fecha": "2025-04-11T04:00:00.000Z",
#             "valor": 988.97
#         },
#         {
#             "fecha": "2025-04-10T04:00:00.000Z",
#             "valor": 1000.01
#         },
#         {
#             "fecha": "2025-04-09T04:00:00.000Z",
#             "valor": 993.89
#         },
#         {
#             "fecha": "2025-04-08T04:00:00.000Z",
#             "valor": 990.68
#         },
#         {
#             "fecha": "2025-04-07T04:00:00.000Z",
#             "valor": 975.82
#         },
#         {
#             "fecha": "2025-04-04T03:00:00.000Z",
#             "valor": 946.59
#         },
#         {
#             "fecha": "2025-04-03T03:00:00.000Z",
#             "valor": 949.83
#         },
#         {
#             "fecha": "2025-04-02T03:00:00.000Z",
#             "valor": 946.28
#         },
#         {
#             "fecha": "2025-04-01T03:00:00.000Z",
#             "valor": 953.07
#         },
#         {
#             "fecha": "2025-03-31T03:00:00.000Z",
#             "valor": 946.1
#         },
#         {
#             "fecha": "2025-03-28T03:00:00.000Z",
#             "valor": 931.75
#         },
#         {
#             "fecha": "2025-03-27T03:00:00.000Z",
#             "valor": 920.98
#         },
#         {
#             "fecha": "2025-03-26T03:00:00.000Z",
#             "valor": 919.92
#         },
#         {
#             "fecha": "2025-03-25T03:00:00.000Z",
#             "valor": 926.41
#         },
#         {
#             "fecha": "2025-03-24T03:00:00.000Z",
#             "valor": 932.14
#         },
#         {
#             "fecha": "2025-03-21T03:00:00.000Z",
#             "valor": 926.15
#         },
#         {
#             "fecha": "2025-03-20T03:00:00.000Z",
#             "valor": 917.76
#         },
#         {
#             "fecha": "2025-03-19T03:00:00.000Z",
#             "valor": 917.97
#         },
#         {
#             "fecha": "2025-03-18T03:00:00.000Z",
#             "valor": 923.32
#         },
#         {
#             "fecha": "2025-03-17T03:00:00.000Z",
#             "valor": 932.36
#         },
#         {
#             "fecha": "2025-03-14T03:00:00.000Z",
#             "valor": 940.2
#         },
#         {
#             "fecha": "2025-03-13T03:00:00.000Z",
#             "valor": 932.28
#         },
#         {
#             "fecha": "2025-03-12T03:00:00.000Z",
#             "valor": 937.45
#         },
#         {
#             "fecha": "2025-03-11T03:00:00.000Z",
#             "valor": 931.13
#         },
#         {
#             "fecha": "2025-03-10T03:00:00.000Z",
#             "valor": 928.25
#         },
#         {
#             "fecha": "2025-03-07T03:00:00.000Z",
#             "valor": 926.52
#         },
#         {
#             "fecha": "2025-03-06T03:00:00.000Z",
#             "valor": 936.7
#         },
#         {
#             "fecha": "2025-03-05T03:00:00.000Z",
#             "valor": 948.87
#         },
#         {
#             "fecha": "2025-03-04T03:00:00.000Z",
#             "valor": 953.11
#         },
#         {
#             "fecha": "2025-03-03T03:00:00.000Z",
#             "valor": 954.22
#         },
#         {
#             "fecha": "2025-02-28T03:00:00.000Z",
#             "valor": 951.21
#         }
#     ]
# }

# %%
import requests

def get_dolar():
    try:
        url = "https://mindicador.cl/api/dolar"
        response = requests.get(url)
        data = response.json()
        
        # Obtener el valor y la fecha más reciente
        valor = data["serie"][0]["valor"]
        fecha = data["serie"][0]["fecha"][:10]
        
        # Devolver un mensaje amigable para el chatbot
        return f"El dólar del {fecha} está en ${valor:,.2f} pesos chilenos."
    
    except Exception as e:
        return f"No pude obtener el valor del dólar. Error: {e}"

# Ejemplo de uso en el chatbot
print(get_dolar())
# Out:
# El dólar del 2025-04-11 está en $988.97 pesos chilenos.

# %%
def get_uf():
    url = "https://mindicador.cl/api/uf"
    response = requests.get(url)
    return response.json()

uf_data = get_uf()
print(json.dumps(uf_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "version": "1.7.0",
#     "autor": "mindicador.cl",
#     "codigo": "uf",
#     "nombre": "Unidad de fomento (UF)",
#     "unidad_medida": "Pesos",
#     "serie": [
#         {
#             "fecha": "2025-04-12T04:00:00.000Z",
#             "valor": 38958.65
#         },
#         {
#             "fecha": "2025-04-11T04:00:00.000Z",
#             "valor": 38952.17
#         },
#         {
#             "fecha": "2025-04-10T04:00:00.000Z",
#             "valor": 38945.69
#         },
#         {
#             "fecha": "2025-04-09T04:00:00.000Z",
#             "valor": 38939.22
#         },
#         {
#             "fecha": "2025-04-08T04:00:00.000Z",
#             "valor": 38934.2
#         },
#         {
#             "fecha": "2025-04-07T04:00:00.000Z",
#             "valor": 38929.19
#         },
#         {
#             "fecha": "2025-04-06T04:00:00.000Z",
#             "valor": 38924.18
#         },
#         {
#             "fecha": "2025-04-05T03:00:00.000Z",
#             "valor": 38919.16
#         },
#         {
#             "fecha": "2025-04-04T03:00:00.000Z",
#             "valor": 38914.15
#         },
#         {
#             "fecha": "2025-04-03T03:00:00.000Z",
#             "valor": 38909.14
#         },
#         {
#             "fecha": "2025-04-02T03:00:00.000Z",
#             "valor": 38904.13
#         },
#         {
#             "fecha": "2025-04-01T03:00:00.000Z",
#             "valor": 38899.12
#         },
#         {
#             "fecha": "2025-03-31T03:00:00.000Z",
#             "valor": 38894.11
#         },
#         {
#             "fecha": "2025-03-30T03:00:00.000Z",
#             "valor": 38889.1
#         },
#         {
#             "fecha": "2025-03-29T03:00:00.000Z",
#             "valor": 38884.1
#         },
#         {
#             "fecha": "2025-03-28T03:00:00.000Z",
#             "valor": 38879.09
#         },
#         {
#             "fecha": "2025-03-27T03:00:00.000Z",
#             "valor": 38874.08
#         },
#         {
#             "fecha": "2025-03-26T03:00:00.000Z",
#             "valor": 38869.08
#         },
#         {
#             "fecha": "2025-03-25T03:00:00.000Z",
#             "valor": 38864.07
#         },
#         {
#             "fecha": "2025-03-24T03:00:00.000Z",
#             "valor": 38859.07
#         },
#         {
#             "fecha": "2025-03-23T03:00:00.000Z",
#             "valor": 38854.06
#         },
#         {
#             "fecha": "2025-03-22T03:00:00.000Z",
#             "valor": 38849.06
#         },
#         {
#             "fecha": "2025-03-21T03:00:00.000Z",
#             "valor": 38844.06
#         },
#         {
#             "fecha": "2025-03-20T03:00:00.000Z",
#             "valor": 38839.06
#         },
#         {
#             "fecha": "2025-03-19T03:00:00.000Z",
#             "valor": 38834.06
#         },
#         {
#             "fecha": "2025-03-18T03:00:00.000Z",
#             "valor": 38829.06
#         },
#         {
#             "fecha": "2025-03-17T03:00:00.000Z",
#             "valor": 38824.06
#         },
#         {
#             "fecha": "2025-03-16T03:00:00.000Z",
#             "valor": 38819.06
#         },
#         {
#             "fecha": "2025-03-15T03:00:00.000Z",
#             "valor": 38814.06
#         },
#         {
#             "fecha": "2025-03-14T03:00:00.000Z",
#             "valor": 38809.06
#         },
#         {
#             "fecha": "2025-03-13T03:00:00.000Z",
#             "valor": 38804.06
#         }
#     ]
# }

# %%
import requests

def get_uf():
    try:
        url = "https://mindicador.cl/api/uf"
        response = requests.get(url)
        data = response.json()
        
        # Obtener el valor y la fecha más reciente
        valor = data["serie"][0]["valor"]
        fecha = data["serie"][0]["fecha"][:10]
        
        # Devolver un mensaje amigable para el chatbot
        return f"El valor de la UF del {fecha} es ${valor:,.2f} pesos chilenos."
    
    except Exception as e:
        return f"No pude obtener el valor de la UF. Error: {e}"

# Ejemplo de uso en el chatbot
print(get_uf())
# Out:
# El valor de la UF del 2025-04-12 es $38,958.65 pesos chilenos.

# %%
import requests

# Variables fácilmente modificables
API_KEY = "602d8a4e7e3a73aae707b32531ef92de"  # Reemplaza esto con tu clave API válida
CIUDAD = "Santiago"  # Reemplaza esto con el nombre de la ciudad que deseas consultar

def get_clima(ciudad):
    # Construir la URL con la ciudad y la clave API
    url = f"http://api.openweathermap.org/data/2.5/weather?q={ciudad}&appid={API_KEY}&lang=es&units=metric"
    
    # Imprimir la URL completa para que puedas verificarla
    print(f"URL construida: {url}")
    
    try:
        # Realizar la solicitud a la API
        response = requests.get(url)
        data = response.json()
        
        if data["cod"] == 200:
            # Extraer información relevante del clima
            temperatura = data["main"]["temp"]
            descripcion = data["weather"][0]["description"]
            humedad = data["main"]["humidity"]
            presion = data["main"]["pressure"]
            viento = data["wind"]["speed"]
            fecha = data["dt"]

            # Devolver toda la información sobre el clima
            return (f"Clima en {ciudad}:\n"
                    f"Temperatura: {temperatura}°C\n"
                    f"Descripción: {descripcion}\n"
                    f"Humedad: {humedad}%\n"
                    f"Presión: {presion} hPa\n"
                    f"Viento: {viento} m/s\n"
                    f"Fecha: {fecha}")
        
        else:
            return f"No se pudo obtener el clima para {ciudad}. Error: {data['message']}"
    
    except Exception as e:
        return f"No pude obtener el clima. Error: {e}"

# Ejecutar la función con la ciudad que definimos al principio
print(get_clima(CIUDAD))
# Out:
# URL construida: http://api.openweathermap.org/data/2.5/weather?q=Santiago&appid=602d8a4e7e3a73aae707b32531ef92de&lang=es&units=metric
# Clima en Santiago:
# Temperatura: 19.95°C
# Descripción: niebla
# Humedad: 48%
# Presión: 1017 hPa
# Viento: 2.68 m/s
# Fecha: 1744476192

# %%
import requests
from googletrans import Translator

# Variables fácilmente modificables
API_KEY = "084a1b8be52f42a6a1c06a9a0ae2777c"  # Reemplaza esto con tu clave API válida
CATEGORY = "business"  # Cambia aquí por la categoría que desees, ej: "business", "sports", "health"
LANGUAGE = "en"  # Idioma de las noticias (español)
NUM_NOTICIAS = 5  # Número de noticias que quieres obtener (modificable)

# Inicializar el traductor
translator = Translator()

def translate_to_spanish(text):
    # Verificar si el texto es None
    if text is None:
        return ""
    
    # Traducir el texto al español
    try:
        translated = translator.translate(text, dest='es')
        return translated.text
    except Exception as e:
        print(f"Error al traducir: {e}")
        return text  # Si no se puede traducir, devolvemos el texto original

def get_noticias():
    # URL para obtener noticias de la categoría seleccionada en el idioma configurado
    url = f"https://newsapi.org/v2/top-headlines?category={CATEGORY}&language={LANGUAGE}&apiKey={API_KEY}"

    # Imprimir la URL construida para ver cómo queda
    print(f"URL construida: {url}")
    
    try:
        # Realizar la solicitud a la API
        response = requests.get(url)
        data = response.json()
        
        if data["status"] == "ok":
            # Extraer las noticias
            noticias = data["articles"]
            
            if noticias:
                # Traducir y devolver las noticias según el número configurado en NUM_NOTICIAS
                noticias_str = ""
                for noticia in noticias[:NUM_NOTICIAS]:
                    # Traducir solo si el título y descripción no son None
                    titular = translate_to_spanish(noticia.get('title', None))
                    descripcion = translate_to_spanish(noticia.get('description', None))
                    
                    noticias_str += f"Titular: {titular}\nDescripción: {descripcion}\nURL: {noticia['url']}\n\n"
                
                return f"Las {NUM_NOTICIAS} últimas noticias de {CATEGORY}:\n\n{noticias_str}"
            else:
                return f"No se encontraron noticias de {CATEGORY} en este momento."
        else:
            return f"Error al obtener noticias. Mensaje: {data.get('message', 'No disponible')}"
    
    except Exception as e:
        return f"No pude obtener las noticias. Error: {e}"

# Ejecutar la función para obtener noticias
print(get_noticias())
# Out:
# URL construida: https://newsapi.org/v2/top-headlines?category=business&language=en&apiKey=084a1b8be52f42a6a1c06a9a0ae2777c
# Las 5 últimas noticias de business:
#
# Titular: El sentimiento del consumidor cae por cuarto mes consecutivo a medida que se disparan las expectativas de inflación - MarketWatch
# Descripción:
# URL: https://www.marketwatch.com/story/consumer-sentiment-falls-for-fourth-straight-month-as-inflation-expectations-soar-dbf722fe
#
# Titular: Larry Fink de BlackRock dice que EE. UU. Está muy cerca de una recesión y puede estar en una ahora - CNBC
# Descripción: El ejecutivo de gestión de activos habló con CNBC sobre el estado de la economía, que ha sido sacudido por los aranceles de la administración Trump.
# URL: https://www.cnbc.com/2025/04/11/blackrocks-larry-fink-says-us-is-very-close-to-a-recession-and-may-be-in-one-now.html
#
# Titular: Le preguntamos a 500 trabajadores manufactureros sobre las tarifas de Trump: el Washington Post
# Descripción: La mayoría de los trabajadores manufactureros dicen que los aranceles los lastimarían.
# URL: https://www.washingtonpost.com/politics/interactive/2025/manufacturing-workers-us-trump-tariffs-poll/
#
# Titular: Parlamento que se retirará sobre el acero británico - BBC
# Descripción: Una fuente dice que el gobierno está buscando "tomar el control" de la compañía después de las conversaciones para salvar la planta de Scunthorpe.
# URL: https://www.bbc.com/news/articles/cx20jr8rjj2o
#
# Titular: Frontier Airlines corta los vuelos después de que la demanda de viajes cayó en marzo - CNBC
# Descripción: Frontier sigue a Delta en la búsqueda de su pronóstico de 2025 por todo el año debido a la incertidumbre económica.
# URL: https://www.cnbc.com/2025/04/11/frontier-airlines-cuts-flights.html
